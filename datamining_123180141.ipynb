# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import sklearn

# %%
df = pd.read_csv('DataRekomen.csv')
df
# Out:
#     Kehadiran  Lingkungan  Kerjasama  Prakarsa Rekomendasi
# 0         5.9         2.1        3.4       2.4       Tidak
# 1         3.1         3.4        1.8       5.1          Ya
# 2         5.5         1.5        1.5       4.0       Tidak
# 3         5.6         4.0        3.5       5.6          Ya
# 4         5.7         3.8        3.2       5.4          Ya
# 5         3.2         3.5        2.4       6.0          Ya
# 6         1.5         3.8        2.1       4.1       Tidak
# 7         5.2         4.1        2.0       3.7          Ya
# 8         5.4         4.2        4.0       5.9          Ya
# 9         2.1         2.3        2.3       4.3       Tidak
# 10        4.2         3.9        4.5       3.8       Tidak
# 11        5.0         3.5        4.2       2.1          Ya
# 12        3.5         3.7        3.8       5.0          Ya
# 13        5.9         3.0        3.9       5.1          Ya
# 14        5.7         3.2        2.6       5.8          Ya
# ...

# %%
Tidak = df[df["Rekomendasi"] == "Tidak"]
Ya = df[df["Rekomendasi"] == "Ya"]

data = (Tidak, Ya)
colors = ("red","green")
groups = ("Tidak", "Ya")

for data, color, group in zip(data, colors, groups):
    x, y = data["Kehadiran"], data["Lingkungan"]
    plt.scatter(x, y, c=color, label=group)

plt.show()

# %%
from sklearn.neighbors import KNeighborsClassifier
X = df.iloc[:, :4]
y = df.iloc[:, 4]
print(X)
print(y)
# Out:
#     Kehadiran  Lingkungan  Kerjasama  Prakarsa
# 0         5.9         2.1        3.4       2.4
# 1         3.1         3.4        1.8       5.1
# 2         5.5         1.5        1.5       4.0
# 3         5.6         4.0        3.5       5.6
# 4         5.7         3.8        3.2       5.4
# 5         3.2         3.5        2.4       6.0
# 6         1.5         3.8        2.1       4.1
# 7         5.2         4.1        2.0       3.7
# 8         5.4         4.2        4.0       5.9
# 9         2.1         2.3        2.3       4.3
# 10        4.2         3.9        4.5       3.8
# 11        5.0         3.5        4.2       2.1
# 12        3.5         3.7        3.8       5.0
# 13        5.9         3.0        3.9       5.1
# 14        5.7         3.2        2.6       5.8
# 15        3.5         1.8        1.5       3.3
# 16        4.0         1.2        3.8       6.0
# 17        3.7         1.5        3.1       2.7
# 18        1.3         3.1        3.4       5.7
# ...

# %%
knn = KNeighborsClassifier(n_neighbors=3)
knn.fit(X,y)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=None, n_neighbors=3, p=2,
#                      weights='uniform')

# %%
#ceycil kehadiran rajin, lingkungan peduli, kerjasama tidak mampu, prakarsa kurang inisiatif
data_test = {
    'Kehadiran' : [4.2],
    'Lingkungan' : [3.5],
    'Kerjasama' : [3.4],
    'Prakarsa' : [3.3]
}

test = pd.DataFrame(data_test)
knn.predict(test)
# Out:
# array(['Ya'], dtype=object)
